# %%
import pandas as pd

# %%
df = pd.read_csv("./data/train_unclean.csv.zip")

# %%
df.head()
# Out:
#    Unnamed: 0 playlist_genre  playlist_genre_id  \
# 0           0            rap                  2
# 1           1            rap                  2
# 2           2            rap                  2
# 3           3            rap                  2
# 4           4            rap                  2
#
#                                               lyrics  acousticness  \
# 0  Especial dedicación a mi Santa Muerte Por prot...      0.106000
# 1  Man, rap today fucking sucks bad, I don't give...      0.148000
# 2  Can't kill me I am the ghost Can't shake me I ...      0.000959
# 3  Go into the night Said you feel sick of the li...      0.030400
# 4  NA Hoy yo soy solo para ti Vamo' a fumar viend...      0.711000
#
#    danceability  energy  instrumentalness  key  liveness  loudness  \
# 0         0.632   0.856          0.003790    5     0.333    -5.583
# 1         0.734   0.584          0.000000    6     0.383    -6.884
# ...

# %%
from transformers import AutoTokenizer
from src.MusicGenreDataset import MusicGenreDatasetWithPreprocess

# %%
model_name = "distilbert-base-uncased"
bertTokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
dataset = MusicGenreDatasetWithPreprocess(
    path_data="./data/train_unclean.csv.zip",
    embedder_model=bertTokenizer,
    embedder_type="bert",
    input_type="unclean",
    store_processed=True,
)
# Out:
# Store processed data is activated. Saving processed data to /home/mephisto/Developments/music-genre-classification ...
# Preprocessing done. Saving to ids_24-02-25_141946.csv.zip ...

# %%
display(dataset.X.head())
display(dataset.y_label.head())
display(dataset.y_id.head())
display(dataset.y_audio.head())
# Out:
#                              0                               1    \
# 0  [101, 9686, 5051, 13247, 102]  [101, 2139, 14808, 21736, 102]
# 1               [101, 2158, 102]                [101, 9680, 102]
# 2               [101, 3102, 102]                [101, 5745, 102]
# 3               [101, 2305, 102]                [101, 2360, 102]
# 4               [101, 6583, 102]          [101, 7570, 2100, 102]
#
#                  2                  3                              4    \
# 0   [101, 2771, 102]   [101, 4203, 102]  [101, 14163, 8743, 2063, 102]
# 1   [101, 2651, 102]   [101, 8239, 102]              [101, 11891, 102]
# 2   [101, 6073, 102]   [101, 2346, 102]               [101, 2674, 102]
# 3   [101, 2514, 102]   [101, 5305, 102]               [101, 2422, 102]
# 4  [101, 10930, 102]  [101, 25176, 102]               [101, 3948, 102]
#
#                  5                               6                        7    \
# ...

# %%
prc = pd.read_csv("ids_24-02-25_141946.csv.zip")
prc.head()
# Out:
#    Unnamed: 0                                             lyrics  \
# 0           0  [101, 9686, 5051, 13247, 102] [101, 2139, 1480...
# 1           1  [101, 2158, 102] [101, 9680, 102] [101, 2651, ...
# 2           2  [101, 3102, 102] [101, 5745, 102] [101, 6073, ...
# 3           3  [101, 2305, 102] [101, 2360, 102] [101, 2514, ...
# 4           4  [101, 6583, 102] [101, 7570, 2100, 102] [101, ...
#
#                                              _lyrics playlist_genre  \
# 0  Especial dedicación a mi Santa Muerte Por prot...            rap
# 1  Man, rap today fucking sucks bad, I don't give...            rap
# 2  Can't kill me I am the ghost Can't shake me I ...            rap
# 3  Go into the night Said you feel sick of the li...            rap
# 4  NA Hoy yo soy solo para ti Vamo' a fumar viend...            rap
#
#    playlist_genre_id  danceability  energy  key  loudness  speechiness  \
# 0                  2         0.632   0.856    5    -5.583       0.0881
# ...
